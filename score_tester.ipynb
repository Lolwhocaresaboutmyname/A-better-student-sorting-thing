# %% [markdown]
# <a href="https://colab.research.google.com/github/Lolwhocaresaboutmyname/A-better-student-sorting-thing/blob/main/score_tester.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Home Assignments:

# %%
score = int(input("Input the score:"))
minscore = int(input("Input how much they need to pass:"))
if score >= minscore:
    print("Pass.")
else:
    print("Fail.")
# Out:
# Input the score:69
# Input how much they need to pass:67
# Pass
